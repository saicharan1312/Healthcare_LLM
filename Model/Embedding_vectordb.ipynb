# %% [markdown]
# # Using Gemini-pro
#
# 1. We are using Google Gemini-pro open source llm - easy to access,
#
# 2. Used instruction embedding and Faiss-cpu vector_db

# %%
#installing the necessary packages
# !pip install python-dotenv==1.00
# !pip install streamlit==1.22.0
# !pip install tiktoken==0.4.0
# !pip install faiss-cpu
# !pip install protobuf~=3.19
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 19.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 19.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 24.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 48.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 44.3 MB/s eta 0:00:00
# ...

# %%
# !pip install InstructorEmbedding
# !pip install langchain==0.0.183
# !pip install sentence-transformers==2.3.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 938.0/938.0 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 21.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.6.3
#     Uninstalling pydantic-2.6.3:
#       Successfully uninstalled pydantic-2.6.3
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 2.9 MB/s eta 0:00:00
# ...

# %%
# We have obtained the api from Google's Gen Ai studio, temp is how good the
# prediction is expected to be like a learning rate of a neural network
from langchain.llms import GooglePalm
llm=GooglePalm(google_api_key="AIzaSyA0fvDmY4gWaA3t5nIZsNLEBLm_87n9hno", temperature = 0.9)

# %%
from langchain_community.llms import Ollama

llm2 = Ollama(model="llama2")

# %%
# we are testing is the Ai_model is working with a sample query
proj=llm("Write process to do project called - Disease prediction and drug recomendation using LLM")
proj
# Out:
# "## Project Process: Disease Prediction and Drug Recommendation Using LLM\n\nThis project will use a language model (LLM) to predict diseases and recommend drugs. The steps involved are as follows:\n\n1. **Data collection.** The first step is to collect data on diseases and drugs. This data can be found in a variety of sources, such as medical databases, clinical trials, and patient records.\n2. **Preprocessing.** The data must be preprocessed before it can be used by the LLM. This involves cleaning the data, removing duplicate entries, and standardizing the format.\n3. **Model training.** The LLM is then trained on the preprocessed data. This process can take a long time, depending on the size of the dataset and the complexity of the model.\n4. **Model evaluation.** Once the model is trained, it must be evaluated to ensure that it is accurate and reliable. This can be done by comparing the model's predictions to the ground truth data.\n5. **Deployment.** The final step is to deploy 
# ...

# %%
# !pip install langchain_community
from langchain_community.document_loaders.csv_loader import CSVLoader
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.9/256.9 kB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.6/66.6 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 14.8 MB/s eta 0:00:00
# ...

# %%
#we are converting the csv file into a set of document with symptoms as source column
loader = CSVLoader(file_path="/content/data_processed.csv", source_column="Symptoms")
data = loader.load()

# %%
data
# Out:
# [Document(page_content="Prescribed_for: ADHD\nDrugName_list: ['Clonidine' 'Bupropion' 'Vyvanse' 'Dexmethylphenidate'\n 'Amphetamine / dextroamphetamine' 'Adderall' 'Aptensio XR' 'Atomoxetine'\n 'Lisdexamfetamine' 'Focalin XR' 'Concerta' 'Guanfacine' 'Ritalin'\n 'Amphetamine' 'Methylphenidate' 'Dextroamphetamine' 'Strattera'\n 'Adzenys XR-ODT' 'Adderall XR' 'Daytrana' 'Methylin' 'Focalin'\n 'Omega-3 polyunsaturated fatty acids' 'Dexedrine' 'Metadate ER'\n 'Metadate CD' 'Wellbutrin XL' 'Intuniv' 'Armodafinil' 'Evekeo' 'Kapvay'\n 'Pristiq' 'Dyanavel XR' 'Quillivant XR' 'Methamphetamine' 'Desoxyn'\n 'Desvenlafaxine' 'Ritalin LA' 'Dextrostat' 'Cylert' 'Modafinil'\n 'Provigil' 'Mydayis' 'Nuvigil' 'Methylin ER' 'Pemoline']\nDisease: Attention deficit hyperactivity disorder\nSymptoms: Inattention carelessness hyperactivity executive dysfunction disinhibition emotional dysregulation impulsivity impaired working memory\nSymptoms_Length: 134\nNumber_of_Drugs: 46", metadata={'source': 'Inattenti
# ...

# %%
from langchain_community.embeddings import HuggingFaceInstructEmbeddings

instructor_embedding = HuggingFaceInstructEmbeddings(
    model_name="google/flan-t5-xl",
    query_instruction="Represent the query for retrieval: "
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name google/flan-t5-xl. Creating a new one with MEAN pooling.
# config.json:   0%|          | 0.00/1.44k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/53.0k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.45G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# ...

# %%
e=instructor_embedding.embed_query("I am suffering from headache, bodypains, cold, fever and abdomen pain")
print("\nLength of embedding: "+ str(len(e)) + '\n')
e[:5]
# Out:
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been removed, please use `SentenceTransformer.device` instead.
# Length of embedding: 2048
# [0.05865855515003204,
#  0.007119693327695131,
#  0.0013864246429875493,
#  -0.003186123911291361,
#  0.007905141450464725]

# %%
from langchain.vectorstores import FAISS
vector_db = FAISS.from_documents(documents=data ,embedding=instructor_embedding)
# Out:
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been removed, please use `SentenceTransformer.device` instead.

# %%
#saving faiss vector db to local system, which contains .faiss file and .pkl
vector_db.save_local("Faiss_vectordb")

# %%
extract_db = vector_db.as_retriever()
rel_ans = extract_db.get_relevant_documents("fever, cold, cough")
rel_ans
# Out:
# WARNING:sentence_transformers.SentenceTransformer:`SentenceTransformer._target_device` has been removed, please use `SentenceTransformer.device` instead.
# [Document(page_content="Prescribed_for: Swine Flu\nDrugName_list: ['Oseltamivir' 'Tamiflu']\nDisease: Influenza\nSymptoms: Fever , runny nose , sore throat , muscle pain , headache , coughing , fatigue\nSymptoms_Length: 78\nNumber_of_Drugs: 2", metadata={'source': 'Fever , runny nose , sore throat , muscle pain , headache , coughing , fatigue', 'row': 544}),
#  Document(page_content="Prescribed_for: Influenza Prophylaxis\nDrugName_list: ['Influenza virus vaccine, inactivated' 'Oseltamivir']\nDisease: Influenza\nSymptoms: Fever , runny nose , sore throat , muscle pain , headache , coughing , fatigue\nSymptoms_Length: 78\nNumber_of_Drugs: 2", metadata={'source': 'Fever , runny nose , sore throat , muscle pain , headache , coughing , fatigue', 'row': 289}),
# ...

# %%
from langchain.prompts import PromptTemplate

prompt_template = """"Given the following context and a question, generate an answer based on this context only.
In the answer try to provide as much text as possible from "response" section in the source document context without making.
If the answer is not found in the context, kindly state "I don't know." Don't try to make up an answer.

CONTEXT: {context}

QUESTION: {question}"""

Prompt = PromptTemplate(template = prompt_template, input_variables=["context", "question"])

# %%
from langchain.chains import RetrievalQA
chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=extract_db,
    input_key="query",
    return_source_documents=True,
    chain_type_kwargs={"prompt":Prompt}
    )

chain("fever and cold?")
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-31-16e61499156f> in <cell line: 2>()
#       1 from langchain.chains import RetrievalQA
# ----> 2 chain = RetrievalQA.from_chain_type(
#       3     llm=llm2,
#       4     chain_type="stuff",
#       5     retriever=extract_db,
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/retrieval_qa/base.py in from_chain_type(cls, llm, chain_type, chain_type_kwargs, **kwargs)
#      89         """Load chain from chain type."""
#      90         _chain_type_kwargs = chain_type_kwargs or {}
# ---> 91         combine_documents_chain = load_qa_chain(
#      92             llm, chain_type=chain_type, **_chain_type_kwargs
#      93         )
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/question_answering/__init__.py in load_qa_chain(llm, chain_type, verbose, callback_manager, **kwargs)
# ...
